# %% [markdown]
# ### Project in Power Shell
# Zarządzanie wersjami Python
# -pyenv version / pyenv versions
# -pyenv global 3.9.7

# %% [markdown]
# ### Poetry
# -poetry new lab
# -foldery (lab, test, pyproject.toml(dependency), README)
# -poetry install

# %% [markdown]
# ### Projekt 1

# %% [markdown]
# Wczytanie pliku tekstowego: histogram wyrazów w pliku (rozkłady)
# #### Wymagania:
# - nazwa pliku jako parametr
# - histogram posortowany
# - ile wyrazów jako parametr
# - minimalna długość słowa
# - lista wyrazów ignorowanych, kolorowy histogram
#
# Biblioteki: ascii_graph, argparse

# %% [markdown]
# #### Praca z plikami
# Komenda: open()
# zwraca

# %%
f = open('/Users/marcinkastek/Desktop/Python/Python Science Applications/lab/lab1/pan-tadeusz.txt')

# %%
with open('/Users/marcinkastek/Desktop/Python/Python Science Applications/lab/lab1/pan-tadeusz.txt',encoding='utf8') as f:
    #print(f.readline(10))  linia z pliku, ile znaków
    #print(f.readlines())  linie z pliku, ile linii
    #print(f.read())       zawartość do stringa
    for line in f: 
        #print(line)
        print(line.strip().split())
# Out:
# ['Adam', 'Mickiewicz']
# []
# ['Pan', 'Tadeusz', 'czyli', 'ostatni', 'zajazd', 'na', 'Litwie']
# []
# ['Księga', 'pierwsza']
# []
# ['Gospodarstwo']
# []
# ['Powrót', 'panicza', '—', 'Spotkanie', 'się', 'pierwsze', 'w', 'pokoiku,', 'drugie', 'u', 'stołu', '—', 'Ważna', 'Sędziego', 'nauka', 'o', 'grzeczności', '—', 'Podkomorzego', 'uwagi', 'polityczne', 'nad', 'modami', '—', 'Początek', 'sporu', 'o', 'Kusego', 'i', 'Sokoła', '—', 'Żale', 'Wojskiego', '—', 'Ostatni', 'Woźny', 'Trybunału', '—', 'Rzut', 'oka', 'na', 'ówczesny', 'stan', 'polityczny', 'Litwy', 'i', 'Europy']
# []
# ['Litwo!', 'Ojczyzno', 'moja!', 'ty', 'jesteś', 'jak', 'zdrowie:']
# ['Ile', 'cię', 'trzeba', 'cenić,', 'ten', 'tylko', 'się', 'dowie,']
# ['Kto', 'cię', 'stracił.', 'Dziś', 'piękność', 'twą', 'w', 'całej', 'ozdobie']
# ['Widzę', 'i', 'opisuję,', 'bo', 'tęsknię', 'po', 'tobie.']
# []
# ['Panno', 'święta,', 'co', 'Jasnej', 'bronisz', 'Częstochowy']
# ...
